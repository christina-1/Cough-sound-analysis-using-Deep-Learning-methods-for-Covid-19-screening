# %% [markdown]
# <center>
#
# # **Cough sound analysis using Deep Learning methods for COVID-19 diagnosis**
#
# ### Division of Information Transmission Systems and Material Technology
#
# ## Christina Ntourma
# </center>

# %% [markdown]
# #Imports

# %%
from sklearn.metrics import confusion_matrix
from imblearn.over_sampling import SMOTE
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
import matplotlib
import numpy as np
import csv
import json
import os
import sys
import pickle
import time

#for loading and visualizing audio files
import librosa
import librosa.display
import pywt
import statistics
import warnings
from os import listdir
from os.path import isfile, join
import random
import pandas as pd
import subprocess
from pathlib import Path
from matplotlib import pyplot as plt
from math import sqrt

# %%
import tensorflow as tf

# %%
from __future__ import absolute_import, division, print_function, unicode_literals # legacy compatibility

from tensorflow import keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Activation
from tensorflow.keras import backend as K
from sklearn.model_selection import KFold
from tensorflow.keras import regularizers
from sklearn import metrics
from sklearn.metrics import recall_score, precision_score, accuracy_score, roc_curve, roc_auc_score

print(tf.__version__)
# Out:
# 2.6.0

# %% [markdown]
# # Initialize Training

# %%
transform_name = 'hcqt'
dataset = 'Cambridge'
batch_size = 32

# %% [markdown]
# # Model Architectures

# %%
def init_model_1(summary, IMG_SHAPE, lr = 0.0001):
    model = keras.Sequential()
    model.add(layers.Conv2D(16, (9, 3), activation='relu', input_shape=IMG_SHAPE))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.2))
    model.add(layers.Conv2D(16, (5, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Dropout(0.2))
    model.add(layers.Flatten())
    model.add(layers.Dropout(0.4))
    model.add(layers.Dense(1, activation='sigmoid'))


    model.compile(optimizer=tf.optimizers.Adam(learning_rate=lr), loss=tf.keras.losses.binary_crossentropy , 
                metrics=[tf.keras.metrics.Recall(name='Recall', thresholds = threshold),
                         tf.keras.metrics.Precision(name='Precision', thresholds = threshold), 
                         tf.keras.metrics.AUC(name='AUC'), 
                         tf.keras.metrics.BinaryAccuracy(name='Accuracy', threshold= threshold),
                         tf.keras.metrics.TruePositives(thresholds = threshold),
                         tf.keras.metrics.FalsePositives(thresholds = threshold),
                         tf.keras.metrics.FalseNegatives(thresholds = threshold),
                         tf.keras.metrics.TrueNegatives(thresholds = threshold)])#, loss_weights = class_weight)
    if summary: 
        model.summary()
    return model

def init_model_2(summary, IMG_SHAPE, lr = 0.0001):
    model = keras.Sequential()
    model.add(layers.Conv2D(4, (5, 5), activation='relu', input_shape=IMG_SHAPE))
    model.add(layers.Dropout(0.3))
    model.add(layers.AveragePooling2D((2, 2)))
    model.add(layers.Conv2D(16, (5, 5), activation='relu'))
    model.add(layers.Dropout(0.3))
    model.add(layers.AveragePooling2D((2, 2)))
    model.add(layers.Conv2D(32, (5, 5), activation='relu'))
    model.add(layers.Dropout(0.3))
    model.add(layers.Flatten())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(optimizer=tf.optimizers.Adam(learning_rate=lr), loss=tf.keras.losses.binary_crossentropy , 
                metrics=[tf.keras.metrics.Recall(name='Recall', thresholds = threshold),
                         tf.keras.metrics.Precision(name='Precision', thresholds = threshold), 
                         tf.keras.metrics.AUC(name='AUC'), 
                         tf.keras.metrics.BinaryAccuracy(name='Accuracy', threshold= threshold),
                         tf.keras.metrics.TruePositives(thresholds = threshold),
                         tf.keras.metrics.FalsePositives(thresholds = threshold),
                         tf.keras.metrics.FalseNegatives(thresholds = threshold),
                         tf.keras.metrics.TrueNegatives(thresholds = threshold)])#, loss_weights = class_weight)

    if summary: 
        model.summary()
    return model

def init_model_3(summary, IMG_SHAPE, lr = 0.0001):
    model = keras.Sequential()
    model.add(layers.Conv2D(10, (7,7), activation='relu', input_shape=IMG_SHAPE))
    model.add(layers.AveragePooling2D((2, 2)))
    model.add(layers.Conv2D(30, (5,5), activation='relu'))  
    model.add(layers.AveragePooling2D((2, 2)))
    model.add(layers.Conv2D(100, (3,3), activation='relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(1, activation='sigmoid'))
    model.compile(optimizer=tf.keras.optimizers.RMSprop(
    learning_rate = 0.001, rho = 0.4, momentum = 0.0), 
    loss = tf.keras.losses.MeanSquaredError(), 
          metrics=[	tf.keras.metrics.Recall(name='Recall', thresholds = threshold),
          tf.keras.metrics.Precision(name='Precision', thresholds = threshold), 
          tf.keras.metrics.AUC(name='AUC'), 
          tf.keras.metrics.BinaryAccuracy(name='Accuracy', threshold= threshold),
          tf.keras.metrics.TruePositives(thresholds = threshold),
          tf.keras.metrics.FalsePositives(thresholds = threshold),
          tf.keras.metrics.FalseNegatives(thresholds = threshold),
          tf.keras.metrics.TrueNegatives(thresholds = threshold)])
    
    if summary: 
        model.summary()
    return model


def init_model_ResNet(summary, IMG_SHAPE):
  resnet_model=tf.keras.applications.ResNet50(input_shape=IMG_SHAPE, include_top=False, weights='imagenet')
  
  RESNET_MODEL=resnet_model.layers[0](resnet_model)

  RESNET_MODEL.trainable=True
  
  dropout_layer = tf.keras.layers.Dropout(rate = 0.5)
  global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

  prediction_layer = tf.keras.layers.Dense(1,activation='sigmoid')

  model = tf.keras.Sequential([RESNET_MODEL, dropout_layer, global_average_layer, prediction_layer])

  model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.0001), loss=tf.keras.losses.BinaryCrossentropy() , 
                metrics=[tf.keras.metrics.Recall(name='Recall', thresholds = threshold),
                         tf.keras.metrics.Precision(name='Precision', thresholds = threshold), 
                         tf.keras.metrics.AUC(name='AUC'), 
                         tf.keras.metrics.BinaryAccuracy(name='Accuracy', threshold= threshold),
                         tf.keras.metrics.TruePositives(thresholds = threshold),
                         tf.keras.metrics.FalsePositives(thresholds = threshold),
                         tf.keras.metrics.FalseNegatives(thresholds = threshold),
                         tf.keras.metrics.TrueNegatives(thresholds = threshold)])
  if summary: 
    model.summary()
  return model

def init_model_DenseNet(summary, IMG_SHAPE):
  densenet_model=tf.keras.applications.DenseNet201(input_shape=IMG_SHAPE, include_top=False, weights='imagenet')
  
  DENSENET_MODEL=densenet_model.layers[0](densenet_model)

  DENSENET_MODEL.trainable=True
  
  dropout_layer = tf.keras.layers.Dropout(rate = 0.5)
  global_average_layer = tf.keras.layers.GlobalAveragePooling2D()

  prediction_layer = tf.keras.layers.Dense(1,activation='sigmoid')

  model = tf.keras.Sequential([DENSENET_MODEL, dropout_layer, global_average_layer, prediction_layer])
  model.compile(optimizer=tf.optimizers.Adam(learning_rate=0.0001), loss=tf.keras.losses.BinaryCrossentropy() , 
                metrics=[tf.keras.metrics.Recall(name='Recall', thresholds = threshold),
                         tf.keras.metrics.Precision(name='Precision', thresholds = threshold), 
                         tf.keras.metrics.AUC(name='AUC'), 
                         tf.keras.metrics.BinaryAccuracy(name='Accuracy', threshold= threshold),
                         tf.keras.metrics.TruePositives(thresholds = threshold),
                         tf.keras.metrics.FalsePositives(thresholds = threshold),
                         tf.keras.metrics.FalseNegatives(thresholds = threshold),
                         tf.keras.metrics.TrueNegatives(thresholds = threshold)])
  if summary: 
    model.summary()
  return model

# %% [markdown]
# # Annotated COUGHVID dataset

# %% [markdown]
# ## Prepare data

# %%
csv_path = 'EPFL_small_labels.csv' # path to csv labels

labels_dict = {}
with open(csv_path) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
      if row[1] == 'neg':
        labels_dict[row[0]] = [0.0]
      elif row[1] == 'pos':
        labels_dict[row[0]] = [1.0]

# %%
image_path = "EPFL/EPFL/" + transform_name + "/"

input_arr = []
labels_arr = []
for i in os.listdir(image_path):
  if i in labels_dict.keys():
    image = tf.keras.preprocessing.image.load_img(image_path + i, color_mode = 'rgb', target_size = (64,64,3))
    labels_arr.append(labels_dict[i])
    input_arr.append(tf.keras.preprocessing.image.img_to_array(image))

# %%
input_arr = np.array(input_arr)
labels_arr = np.array(labels_arr)

# %%
tmp = list(zip(input_arr, labels_arr))

random.shuffle(tmp)

input_arr, labels_arr = zip(*tmp)
input_arr = np.array(input_arr)
labels_arr = np.array(labels_arr)
print(labels_arr)
# Out:
# [[0.]
#  [1.]
#  [0.]
#  ...
#  [0.]
#  [0.]
#  [0.]]

# %%
data_size, img_rows, img_cols, img_channels = input_arr.shape

# %%
# we user prefetch https://www.tensorflow.org/api_docs/python/tf/data/Dataset#prefetch 
# see also AUTOTUNE
# the dataset is now "infinite"

BATCH_SIZE = 32
IMG_SHAPE = (img_rows, img_cols, img_channels)
threshold = 0.5
AUTOTUNE = tf.data.experimental.AUTOTUNE # https://www.tensorflow.org/guide/data_performance

# %%
def _input_fn(x, y, BATCH_SIZE, data_size, IMG_SIZE): ### to data size prostethike meta

  x_reshaped = []
  print(x.shape)
  for i in x:
    x_reshaped.append(tf.image.resize(i, IMG_SIZE))
  x_reshaped = np.array(x_reshaped)
  print(x_reshaped.shape)
  ds = tf.data.Dataset.from_tensor_slices((x_reshaped,y)) 
  ds = ds.shuffle(buffer_size=data_size) # https://datascience.stackexchange.com/questions/89316/tensorflows-shufflebuffer-size
  ds = ds.repeat() # https://stackoverflow.com/questions/53514495/what-does-batch-repeat-and-shuffle-do-with-tensorflow-dataset
  ds = ds.batch(BATCH_SIZE)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

# steps_per_epoch and validation_steps for training and validation: https://www.tensorflow.org/guide/keras/train_and_evaluate
def train_model(model, train_ds, validation_ds, weights, epochs = 10, steps_per_epoch = 2, validation_steps = 1):
  history = model.fit(train_ds, epochs=epochs, steps_per_epoch=steps_per_epoch, validation_data=validation_ds, validation_steps=validation_steps, class_weight = weights)
  return(history)

# %% [markdown]
# ## Functions used during training and testing

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
  plt.figure(figsize=(15, 15))
  plt.suptitle('Training Curves')
  # plot loss
  
  plt.subplot(521)
  plt.title('Binary Cross Entropy Loss')
  plt.plot(history.history['loss'], color='blue', label='train')
  plt.plot(history.history['val_loss'], color='orange', label='val')
  plt.legend(loc='upper right')
  # plot accuracy
  plt.subplot(522)
  plt.title('Classification Accuracy')
  plt.plot(history.history['Accuracy'], color='blue', label='train')
  plt.plot(history.history['val_Accuracy'], color='orange', label='val')
  plt.legend(loc='lower right')
  plt.subplot(523)
  plt.title('Classification Recall')
  plt.plot(history.history['Recall'], color='blue', label='train')
  plt.plot(history.history['val_Recall'], color='orange', label='val')
  plt.legend(loc='lower right')
  plt.subplot(524)
  plt.title('Classification Precision')
  plt.plot(history.history['Precision'], color='blue', label='train')
  plt.plot(history.history['val_Precision'], color='orange', label='val')
  plt.legend(loc='lower right')
  plt.subplot(525)
  plt.title('Classification AUC')
  plt.plot(history.history['AUC'], color='blue', label='train')
  plt.plot(history.history['val_AUC'], color='orange', label='val')
  plt.legend(loc='lower right')
  return plt

# %%
def ensemble_split(x_train, y_train):
  neg = 0
  pos = 0

  x_train_set = []
  y_train_set = []

  tmp_1x = []
  tmp_2x = []
  tmp_3x = []
  tmp_4x = []

  tmp_1y = []
  tmp_2y = []
  tmp_3y = []
  tmp_4y = []

  tmp_x = []
  tmp_y = []
  
  for i in y_train:
    if i[0] == 0.0:
      neg = neg + 1
    else:
      pos = pos + 1

  print("Train set contains", pos, "covid samples and", neg, "non-covid samples")
  neg_samples = round(neg/4)

  train_neg = []
  train_pos = []
  index = 0

  for i in y_train:
    if i[0] == 0.0:
      train_neg.append(index)
    elif i[0] == 1.0:
      train_pos.append(index)
    index = index + 1
  
  index_1 = train_neg[0:neg_samples]
  index_2 = train_neg[neg_samples:2*neg_samples]
  index_3 = train_neg[2*neg_samples:3*neg_samples]
  index_4 = train_neg[3*neg_samples:]

  for i in index_1:
    tmp_1x.append(x_train[i])
    tmp_1y.append(y_train[i])

  for i in index_2:
    tmp_2x.append(x_train[i])
    tmp_2y.append(y_train[i])

  for i in index_3:
    tmp_3x.append(x_train[i])
    tmp_3y.append(y_train[i])

  for i in index_4:
    tmp_4x.append(x_train[i])
    tmp_4y.append(y_train[i])
  
  for i in train_pos:
    tmp_x.append(x_train[i])
    tmp_y.append(y_train[i])

  tmp_x = np.array(tmp_x)
  tmp_y = np.array(tmp_y)

  tmp_1x = np.array(tmp_1x)
  tmp_2x = np.array(tmp_2x)
  tmp_3x = np.array(tmp_3x)
  tmp_4x = np.array(tmp_4x)

  tmp_1y = np.array(tmp_1y)
  tmp_2y = np.array(tmp_2y)
  tmp_3y = np.array(tmp_3y)
  tmp_4y = np.array(tmp_4y)

  x_train_set.append(np.concatenate((tmp_1x,tmp_x), axis = 0))
  x_train_set.append(np.concatenate((tmp_2x,tmp_x), axis = 0))
  x_train_set.append(np.concatenate((tmp_3x,tmp_x), axis = 0))
  x_train_set.append(np.concatenate((tmp_4x,tmp_x), axis = 0))

  y_train_set.append(np.concatenate((tmp_1y,tmp_y), axis = 0))
  y_train_set.append(np.concatenate((tmp_2y,tmp_y), axis = 0))
  y_train_set.append(np.concatenate((tmp_3y,tmp_y), axis = 0))
  y_train_set.append(np.concatenate((tmp_4y,tmp_y), axis = 0))

  return x_train_set, y_train_set

# %%
def evaluate_trained_model(x_test, y_test, new_model, steps_per_epoch = 10):
    loss, recall, precision, auc, acc, tp, fp, fn, tn = new_model.evaluate(x_test, y_test, steps = steps_per_epoch)
    print('Restored model, accuracy: {:5.2f}%'.format(100 * acc))
    print('Restored model, recall: {:5.2f}%'.format(100 * recall))
    print('Restored model, precision: {:5.2f}%'.format(100 * precision))
    print('Restored model, AUC: {:5.2f}%'.format(100 * auc))

    print('Restored model, true positives: '.format(tp))
    print('Restored model, false positives: '.format(fp))
    print('Restored model, false negatives: '.format(fn))
    print('Restored model, true negatives: '.format(tn))
    return recall, precision, auc, acc, tp, fp, fn, tn

# %%
def get_predictions(model, x_test, y_test, threshold, steps_per_epoch):
    pred=model.predict(x_test, steps = steps_per_epoch)
    
    probabilities = []
    predictions = []
    for i in pred:
        if i[0] >= threshold:
            predictions.append(1.0)
        else:
            predictions.append(0.0)
    for i in pred:
        probabilities.append(i[0])
    
    return probabilities, predictions, pred

# %%
def print_average_results(probabilities_list, y_test, threshold):
    probabilities = calculate_mean_probabilities(probabilities_list)
    predictions = get_total_predictions(probabilities, threshold)
    (acc, recall, precision, auc, specificity)  = calculate_metrics(predictions, probabilities, y_test, threshold)
    tpr, fpr, thresholds = plot_roc(y_test, probabilities)
    return (acc, recall, precision, auc, specificity)  


def calculate_mean_probabilities(probabilities_list):
  probabilities = []
  
  for i in range(len(probabilities_list[0])):
    mean_probability = np.mean([probabilities_list[0][i], probabilities_list[1][i], probabilities_list[2][i], probabilities_list[3][i]])
    probabilities.append([mean_probability])
  
  probabilities = np.array(probabilities)
  return probabilities

def get_total_predictions(probabilities, threshold):
  predictions = []
  for i in probabilities:
    if i[0] >= threshold:
      predictions.append(1.0)
    elif i[0] < threshold:
      predictions.append(0.0)
  
  predictions = np.array(predictions)
  return predictions

def calculate_metrics(predictions, probabilities, y_test, threshold):
  acc = accuracy_score(y_test, predictions)*100
  recall = recall_score(y_test, predictions, zero_division = 0)*100
  precision  = precision_score(y_test, predictions, zero_division = 0)*100
  auc = roc_auc_score(y_test, probabilities)*100
  tn, fp, fn, tp = confusion_matrix(y_test, predictions).ravel()
  specificity = tn / (tn+fp)
  print("Accuracy: ", acc, "%")
  print("Recall: ", recall, "%")
  print("Precision: ",precision, "%")
  print("AUC: ",auc, "%")
  print("Specificity: ", specificity*100, "%")

  return (acc, recall, precision, auc, specificity*100)

# %%
# Plot ROC curve

def plot_roc(y_true, probabilities):
    y_true_int = []
    for i in y_true:
        y_true_int.append(int(i))

    # calculate roc curves
    fpr, tpr, thresholds = roc_curve(y_true_int, probabilities)
    # plot the roc curve for the model
    plt.subplot(526)
    plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
    plt.plot(fpr, tpr, marker='.', label='CNN Model')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    # show the plot
    plt.show()
    print(roc_auc_score(y_true_int, probabilities), "AUC")
    return tpr, fpr, thresholds

# %%
def calculate_weights(y_train):
    no_neg = 0
    no_pos = 0
    for i in y_train:
        if i[0] == 0.0:
            no_neg = no_neg + 1
        else:
            no_pos = no_pos + 1
    print("Number of negatives", no_neg, "Number of positives", no_pos)

    ratio = (no_pos*100)/(no_neg+no_pos)
    w_0 = ratio
    w_1 = 100-ratio

    print("w_0:", w_0)
    print("w_1:", w_1)


    # Give class weights
    class_weight = {0: w_0,
                    1: w_1}
    return class_weight

# %%
def folds_split_stratified():
  folds_split = 0.2

  folds = [[], [], [], [], []]
  data_size = len(labels_arr)
  print("Data size:", data_size)

  ###folds contain indices
  ind_flag = [0] * len(labels_arr)

  cnt = 0 
  x = folds_split
  
  non_covid = 0
  covid = 0

  for file in labels_arr:
    if file == [0.0]:
      non_covid = non_covid + 1
    else:
      covid = covid + 1

  non_covid_percentage = non_covid/(covid + non_covid)
  covid_percentage = covid/(covid + non_covid)
  print('covid', covid)
  print('non-covid', non_covid)
  print("Non covid percentage:", non_covid_percentage)
  print("Covid percentage:", covid_percentage)
  
  for i in range(5):
    neg = 0
    pos = 0
    while len(folds[i]) < folds_split*data_size :
      for ind in range(data_size):
        if ind_flag[ind] == 0:
          if labels_arr[ind] == [0.0] and neg < folds_split*non_covid and i!=4:
            neg = neg + 1
            folds[i].append(ind)
            ind_flag[ind] = 1
            cnt = cnt + 1

          elif labels_arr[ind] == [1.0] and pos < folds_split*covid and i!=4:
            pos = pos + 1
            folds[i].append(ind)
            ind_flag[ind] = 1
            cnt = cnt + 1

          elif len(folds[i]) >= folds_split*data_size:
            break

          elif i==4:
            if labels_arr[ind] == [0.0]:
              neg = neg + 1
              folds[i].append(ind)
              ind_flag[ind] = 1
              cnt = cnt + 1
            elif labels_arr[ind] == [1.0]:
              pos = pos + 1
              folds[i].append(ind)
              ind_flag[ind] = 1
              cnt = cnt + 1
              
        else:
          continue
      if i == 4 and cnt == data_size:
        break
  return folds

# %%
def train_with_5_folds_ensemble(splitted_folds):
  PROBABILITIES_LIST = []
  PREDICTIONS_LIST = []
  ACCURACY = []
  RECALL = []
  PRECISION = []
  AUC = []
  SPECIFICITY = []
  PREDICTIONS = []
  ACTUAL = []
  new_m = []
  j = 0

  for fold in splitted_folds:

    X_train = []
    X_val = []
    X_test = []

    y_train = []
    y_val = []
    y_test = []


    for files in fold[0]:
      X_train.append(input_arr[files]/255.0)
      y_train.append(labels_arr[files])
    for files in fold[1]:
      X_val.append(input_arr[files]/255.0)
      y_val.append(labels_arr[files])
    for files in fold[2]:
      X_test.append(input_arr[files]/255.0)
      y_test.append(labels_arr[files])


    print("Initial train set", len(X_train), len(y_train))
    print("Initial validation set", len(X_val), len(y_val))
    print("Initial test set", len(X_test), len(y_test))
    
    X_train = np.array(X_train)
    X_val = np.array(X_val)
    X_test = np.array(X_test)

    y_train = np.array(y_train)
    y_val = np.array(y_val)
    y_test = np.array(y_test)

    neg = 0 
    pos = 0
    for i in y_train:
      if i[0] == 1.0:
        pos = pos + 1
      elif i[0] == 0.0:
        neg = neg + 1

    print("Initial train set: Negative samples:", neg, "|| Positive samples:", pos, "|| Total_samples:", neg+pos)

    neg = 0 
    pos = 0
    for i in y_test:
      if i[0] == 1.0:
        pos = pos + 1
      elif i[0] == 0.0:
        neg = neg + 1

    print("Initial test set: Negative samples:", neg, "|| Positive samples:", pos, "|| Total_samples:", neg+pos) 

    neg = 0 
    pos = 0
    for i in y_val:
      if i[0] == 1.0:
        pos = pos + 1
      elif i[0] == 0.0:
        neg = neg + 1

    print("Initial validation set: Negative samples:", neg, "|| Positive samples:", pos, "|| Total_samples:", neg+pos)

    (PRED, test, acc, recall, precision, auc, specificity, m) = train_with_ensemble(X_train, y_train, X_val, y_val, X_test, y_test)
    
    RECALL.append(recall)
    PRECISION.append(precision)
    AUC.append(auc)
    ACCURACY.append(acc)
    SPECIFICITY.append(specificity)
    PREDICTIONS.append(PRED)
    ACTUAL.append(test)


  print("Accuracy:", round(np.mean(ACCURACY),4), "%")
  print("Recall:", round(np.mean(RECALL),4), "%")
  print("Precision:", round(np.mean(PRECISION),4), "%")
  print("AUC:", round(np.mean(AUC),4), "%")
  print("Specificity:", round(np.mean(SPECIFICITY),4), "%")
  return PREDICTIONS, ACTUAL

# %%
def train_with_ensemble(X_train, y_train, X_val, y_val, X_test, y_test):
    img = 100
    IMG_SHAPE = (img, img, 3)
    new_models = []
    validation_ds =_input_fn(X_val,y_val, BATCH_SIZE, data_size, (img,img)) #PrefetchDataset object

    test_ds =_input_fn(X_test, y_test, BATCH_SIZE, data_size, (img,img)) #PrefetchDataset object

    x_train_set, y_train_set = ensemble_split(X_train, y_train)

    x_reshaped = []
    for i in X_test:
      x_reshaped.append(tf.image.resize(i, (img, img)))
    x_reshaped = np.array(x_reshaped)

    PROBABILITIES_LIST = []
    PREDICTIONS_LIST = []
    for i in range(len(x_train_set)):
      weights = calculate_weights(y_train_set[i])

      test_steps = int(len(y_test)/BATCH_SIZE)
      train_ds =_input_fn(x_train_set[i], y_train_set[i], BATCH_SIZE, data_size, (img,img)) #PrefetchDataset object
      
      
      model = init_model_2(True, IMG_SHAPE)
      
      model_history = train_model(model, train_ds, validation_ds, weights, 30, len(y_train_set[i])/BATCH_SIZE, 10)
    
      summarize_diagnostics(model_history)

      recall, precision, auc, acc, tp, fp, fn, tn = evaluate_trained_model(x_reshaped, y_test, model, steps_per_epoch = test_steps)
      
      probabilities, predictions, pred = get_predictions(model, x_reshaped, y_test, threshold, test_steps)

      PROBABILITIES_LIST.append(probabilities)
      PREDICTIONS_LIST.append(predictions)
      new_models.append(model)
      
    (acc, recall, precision, auc, specificity) = print_average_results(PROBABILITIES_LIST, y_test, threshold)
    print()

    print("-------------------------------------------------------------------------------------------------------------------------------------------")
    print("-------------------------------------------------------------------------------------------------------------------------------------------")
    return (PROBABILITIES_LIST, y_test, acc, recall, precision, auc,specificity, new_models)

# %% [markdown]
# ## Training and testing

# %%
folds = folds_split_stratified()
# Out:
# Data size: 2804
# covid 553
# non-covid 2251
# Non covid percentage: 0.8027817403708987
# Covid percentage: 0.19721825962910128

# %%
for f in folds:
  neg = 0
  pos = 0
  for ff in f:
    if labels_arr[ff] == [0.0]:
      neg = neg + 1
    else:
      pos =pos + 1
  print("Negative:", neg/(neg+pos), "positive:", pos/(neg+pos))
  print("-------------------------------------------------------------")
# Out:
# Negative: 0.802491103202847 positive: 0.19750889679715303
# -------------------------------------------------------------
# Negative: 0.803921568627451 positive: 0.19607843137254902
# -------------------------------------------------------------
# Negative: 0.802491103202847 positive: 0.19750889679715303
# -------------------------------------------------------------
# Negative: 0.802491103202847 positive: 0.19750889679715303
# -------------------------------------------------------------
# Negative: 0.8025134649910234 positive: 0.19748653500897667
# -------------------------------------------------------------

# %%
for f in folds[0]:
  if f in folds[1] or f in folds[2] or f in folds[3] or f in folds[4]:
    print("The same sample exists in more than one folds")

for f in folds[1]:
  if f in folds[0] or f in folds[2] or f in folds[3] or f in folds[4]:
    print("The same sample exists in more than one folds")

for f in folds[2]:
  if f in folds[0] or f in folds[1] or f in folds[3] or f in folds[4]:
    print("The same sample exists in more than one folds")

for f in folds[3]:
  if f in folds[0] or f in folds[1] or f in folds[2] or f in folds[4]:
    print("The same sample exists in more than one folds")

for f in folds[4]:
  if f in folds[0] or f in folds[1] or f in folds[2] or f in folds[3]:
    print("The same sample exists in more than one folds")

# %%
# concatenate folds to create 5 different splits of the dataset into train, validation and test set

tmp = []
splitted_folds = []
for i in range(len(folds)):
  print(len(folds[i]))

tmp.append(list(folds[1]+folds[2]+folds[3])) # train
tmp.append(folds[4]) # validation
tmp.append(list(folds[0])) # test
splitted_folds.append(list(tmp))
tmp = []

tmp.append(list(folds[0]+folds[2]+folds[4]))
tmp.append(folds[3])
tmp.append(list(folds[1]))
splitted_folds.append(list(tmp))
tmp = []

tmp.append(list(folds[0]+folds[3]+folds[4]))
tmp.append(folds[1])
tmp.append(list(folds[2]))
splitted_folds.append(list(tmp))
tmp = []

tmp.append(list(folds[1]+folds[2]+folds[4]))
tmp.append(folds[0])
tmp.append(list(folds[3]))
splitted_folds.append(list(tmp))
tmp = []

tmp.append(list(folds[0]+folds[1]+folds[3]))
tmp.append(folds[2])
tmp.append(list(folds[4]))
splitted_folds.append(list(tmp))
# Out:
# 562
# 561
# 562
# 562
# 557

# %%
for f in splitted_folds:
  print("Train set contains", len(f[0]), "samples, validation set contains", len(f[1]), "samples, test set contains", len(f[2]), "samples")
# Out:
# Train set contains 1685 samples, validation set contains 557 samples, test set contains 562 samples
# Train set contains 1681 samples, validation set contains 562 samples, test set contains 561 samples
# Train set contains 1681 samples, validation set contains 561 samples, test set contains 562 samples
# Train set contains 1680 samples, validation set contains 562 samples, test set contains 562 samples
# Train set contains 1685 samples, validation set contains 562 samples, test set contains 557 samples

# %%
# statistics for each fold

for ff in folds:
  neg = 0
  pos = 0
  for i in ff:
    if labels_arr[i] == [0.0]:
      neg = neg + 1
    else:
      pos = pos + 1
  print("Negative:", neg, "total", pos+neg, "Percentage:", (neg*100)/(neg+pos))
  print("Positive:", pos, "total", pos+neg, "Percentage:", (pos*100)/(neg+pos))
  print("-------------------------------------------------------------------------")
# Out:
# Negative: 451 total 562 Percentage: 80.2491103202847
# Positive: 111 total 562 Percentage: 19.750889679715304
# -------------------------------------------------------------------------
# Negative: 451 total 561 Percentage: 80.3921568627451
# Positive: 110 total 561 Percentage: 19.607843137254903
# -------------------------------------------------------------------------
# Negative: 451 total 562 Percentage: 80.2491103202847
# Positive: 111 total 562 Percentage: 19.750889679715304
# -------------------------------------------------------------------------
# Negative: 451 total 562 Percentage: 80.2491103202847
# Positive: 111 total 562 Percentage: 19.750889679715304
# -------------------------------------------------------------------------
# Negative: 447 total 557 Percentage: 80.25134649910234
# Positive: 110 total 557 Percentage: 19.748653500897667
# -------------------------------------------------------------------------

# %%
PRED, ACTUAL = train_with_5_folds_ensemble(splitted_folds)
# Out:
# Initial train set 1685 1685
# Initial validation set 557 557
# Initial test set 562 562
# Initial train set: Negative samples: 1353 || Positive samples: 332 || Total_samples: 1685
# Initial test set: Negative samples: 451 || Positive samples: 111 || Total_samples: 562
# Initial validation set: Negative samples: 447 || Positive samples: 110 || Total_samples: 557
# (557, 64, 64, 3)
# (557, 100, 100, 3)
# (562, 64, 64, 3)
# (562, 100, 100, 3)
# Train set contains 332 covid samples and 1353 non-covid samples
# Number of negatives 338 Number of positives 332
# w_0: 49.55223880597015
# w_1: 50.44776119402985
# (670, 64, 64, 3)
# (670, 100, 100, 3)
# Model: "sequential_40"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_120 (Conv2D)          (None, 96, 96, 4)         304
# _________________________________________________________________
# dropout_160 (Dropout)        (None, 96, 96, 4)         0
# _________________________________________________________________
# average_pooling2d_80 (Averag (None, 48, 48, 4)         0
# _________________________________________________________________
# conv2d_121 (Conv2D)          (None, 44, 44, 16)        1616
# _________________________________________________________________
# dropout_161 (Dropout)        (None, 44, 44, 16)        0
# _________________________________________________________________
# average_pooling2d_81 (Averag (None, 22, 22, 16)        0
# _________________________________________________________________
# conv2d_122 (Conv2D)          (None, 18, 18, 32)        12832
# _________________________________________________________________
# dropout_162 (Dropout)        (None, 18, 18, 32)        0
# _________________________________________________________________
# flatten_40 (Flatten)         (None, 10368)             0
# _________________________________________________________________
# dropout_163 (Dropout)        (None, 10368)             0
# _________________________________________________________________
# dense_40 (Dense)             (None, 1)                 10369
# =================================================================
# Total params: 25,121
# Trainable params: 25,121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 20/20 [==============================] - 5s 135ms/step - loss: 34.7229 - Recall: 0.3363 - Precision: 0.4766 - AUC: 0.4984 - Accuracy: 0.4881 - true_positives_40: 112.0000 - false_positives_40: 123.0000 - false_negatives_40: 221.0000 - true_negatives_40: 216.0000 - val_loss: 0.6932 - val_Recall: 0.5775 - val_Precision: 0.2426 - val_AUC: 0.5368 - val_Accuracy: 0.5063 - val_true_positives_40: 41.0000 - val_false_positives_40: 128.0000 - val_false_negatives_40: 30.0000 - val_true_negatives_40: 121.0000
# Epoch 2/30
# 20/20 [==============================] - 1s 27ms/step - loss: 34
# Model: "sequential_41"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_123 (Conv2D)          (None, 96, 96, 4)         304
# _________________________________________________________________
# dropout_164 (Dropout)        (None, 96, 96, 4)         0
# _________________________________________________________________
# average_pooling2d_82 (Averag (None, 48, 48, 4)         0
# _________________________________________________________________
# conv2d_124 (Conv2D)          (None, 44, 44, 16)        1616
# _________________________________________________________________
# dropout_165 (Dropout)        (None, 44, 44, 16)        0
# _________________________________________________________________
# average_pooling2d_83 (Averag (None, 22, 22, 16)        0
# _________________________________________________________________
# conv2d_125 (Conv2D)          (None, 18, 18, 32)        12832
# _________________________________________________________________
# dropout_166 (Dropout)        (None, 18, 18, 32)        0
# _________________________________________________________________
# flatten_41 (Flatten)         (None, 10368)             0
# _________________________________________________________________
# dropout_167 (Dropout)        (None, 10368)             0
# _________________________________________________________________
# dense_41 (Dense)             (None, 1)                 10369
# =================================================================
# Total params: 25,121
# Trainable params: 25,121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 20/20 [==============================] - 4s 72ms/step - loss: 35.0249 - Recall: 0.4655 - Precision: 0.4921 - AUC: 0.4792 - Accuracy: 0.4970 - true_positives_41: 155.0000 - false_positives_41: 160.0000 - false_negatives_41: 178.0000 - true_negatives_41: 179.0000 - val_loss: 0.6849 - val_Recall: 0.2034 - val_Precision: 0.1290 - val_AUC: 0.4531 - val_Accuracy: 0.6000 - val_true_positives_41: 12.0000 - val_false_positives_41: 81.0000 - val_false_negatives_41: 47.0000 - val_true_negatives_41: 180.0000
# Epoch 2/30
# 20/20 [==============================] - 1s 27ms/step - loss: 34.7369 - Recall: 0.5438 - Precision: 0.4972 - AUC: 0.5126 - Accuracy: 0.5045 - true_positives_41: 180.0000 - false_positives_41: 182.0000 - false_negatives_41: 151.0000 - true_negatives_41: 159.0000 - val_loss: 0.6934 - val_Recall: 0.4655 - val_Precision: 0.1742 - val_AUC: 0.4835 - val_Accuracy: 0.5031 - val_true_positives_41: 27.0000 - val_false_positives_41: 128.0000 - val_false_negatives_41: 31.0000 - val_true_negatives_41: 134.0000
# Epoch 3/30
# 20/20 [==============================] - 1s 27ms/step - loss: 34.6549 - Recall: 0.6131 - Precision: 0.5037 - AUC: 0.5169 - Accuracy: 0.5045 - true_positives_41: 206.0000 - false_positives_41: 203.0000 - false_negatives_41: 130.0000 - true_negatives_41: 133.0000 - val_loss: 0.6994 - val_Recall: 0.5000 - val_Precision: 0.1693 - val_AUC: 0.4265 - val_Accuracy: 0.4094 - val_true_positives_41: 32.0000 - val_false_positives_41: 157.0000 - val_false_negatives_41: 32.0000 - val_true_negatives_41: 99.0000
# Epoch 4/30
# 20/20 [==============================] - 1s 27ms/step - loss: 34.4761 - Recall: 0.6435 - Precision: 0.5338 - AUC: 0.5501 - Accuracy: 0.5476 - true_positives_41: 213.0000 - false_positives_41: 186.0000 - false_negatives_41: 118.0000 - true_negatives_41: 155.0000 - val_loss: 0.6946 - val_Recall: 0.5246 - val_Precision: 0.1916 - val_AUC: 0.4878 - val_Accuracy: 0.4875 - val_true_positives_41: 32.0000 - val_false_positives_41: 135.0000 - val_false_negatives_41: 29.0000 - val_true_negatives_41: 124.0000
# Epoch 5/30
# 20/20 [==============================] - 1s 28ms/step - loss: 34
# 20/20 [==============================] - 1s 28ms/step - loss: 32.9793 - Recall: 0.6446 - Precision: 0.5707 - AUC: 0.6492 - Accuracy: 0.5848 - true_positives_41: 214.0000 - false_positives_41: 161.0000 - false_negatives_41: 118.0000 - true_negatives_41: 179.0000 - val_loss: 0.7009 - val_Recall: 0.5000 - val_Precision: 0.2051 - val_AUC: 0.4966 - val_Accuracy: 0.5125 - val_true_positives_41: 32.0000 - val_false_positives_41: 124.0000 - val_false_negatives_41: 32.0000 - val_true_negatives_41: 132.0000
# Epoch 29/30
# 20/20 [==============================] - 1s 28ms/step - loss: 32.9061 - Recall: 0.6235 - Precision: 0.6035 - AUC: 0.6538 - Accuracy: 0.6116 - true_positives_41: 207.0000 - false_positives_41: 136.0000 - false_negatives_41: 125.0000 - true_negatives_41: 204.0000 - val_loss: 0.7082 - val_Recall: 0.5312 - val_Precision: 0.1965 - val_AUC: 0.5417 - val_Accuracy: 0.4719 - val_true_positives_41: 34.0000 - val_false_positives_41: 139.0000 - val_false_negatives_41: 30.0000 - val_true_negatives_41: 117.0000
# Epoch 30/30
# 20/20 [==============================] - 1s 28ms/step - loss: 32.2253 - Recall: 0.6737 - Precision: 0.6098 - AUC: 0.6861 - Accuracy: 0.6235 - true_positives_41: 225.0000 - false_positives_41: 144.0000 - false_negatives_41: 109.0000 - true_negatives_41: 194.0000 - val_loss: 0.7197 - val_Recall: 0.5472 - val_Precision: 0.1629 - val_AUC: 0.5415 - val_Accuracy: 0.4594 - val_true_positives_41: 29.0000 - val_false_positives_41: 149.0000 - val_false_negatives_41: 24.0000 - val_true_negatives_41: 118.0000
# 17/17 [==============================] - 1s 14ms/step - loss: 0.7300 - Recall: 0.5225 - Precision: 0.1953 - AUC: 0.5050 - Accuracy: 0.4804 - true_positives_41: 58.0000 - false_positives_41: 239.0000 - false_negatives_41: 53.0000 - true_negatives_41: 212.0000
# Restored model, accuracy: 48.04%
# Restored model, recall: 52.25%
# Restored model, precision: 19.53%
# Restored model, AUC: 50.50%
# Restored model, true positives:
# Restored model, false positives:
# Restored model, false negatives:
# Restored model, true negatives:
# Number of negatives 338 Number of positives 332
# w_0: 49.55223880597015
# w_1: 50.44776119402985
# (670, 64, 64, 3)
# (670, 100, 100, 3)
# Model: "sequential_42"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_126 (Conv2D)          (None, 96, 96, 4)         304
# _________________________________________________________________
# dropout_168 (Dropout)        (None, 96, 96, 4)         0
# _________________________________________________________________
# average_pooling2d_84 (Averag (None, 48, 48, 4)         0
# _________________________________________________________________
# conv2d_127 (Conv2D)          (None, 44, 44, 16)        1616
# _________________________________________________________________
# dropout_169 (Dropout)        (None, 44, 44, 16)        0
# _________________________________________________________________
# average_pooling2d_85 (Averag (None, 22, 22, 16)        0
# _________________________________________________________________
# conv2d_128 (Conv2D)          (None, 18, 18, 32)        12832
# _________________________________________________________________
# dropout_170 (Dropout)        (None, 18, 18, 32)        0
# _________________________________________________________________
# flatten_42 (Flatten)         (None, 10368)             0
# _________________________________________________________________
# dropout_171 (Dropout)        (None, 10368)             0
# _________________________________________________________________
# dense_42 (Dense)             (None, 1)                 10369
# =================================================================
# Total params: 25,121
# Trainable params: 25,121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
#
------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------------
# Accuracy: 49.383 %
# Recall: 58.4275 %
# Precision: 21.3946 %
# AUC: 54.079 %
# Specificity: 47.1604 %

# %% [markdown]
# ## Hosmer-Lemeshow test
# `data.json` files contain predicted and actual values for each sample of the test set, for each one of the five different splits of the dataset resulting from the 5-fold cross validation. These values are given as input to the following R code, to calculate the Hosmer-Lemeshow test statistic of the model.
#
#
# ```
# library(ResourceSelection)
# hl <- hoslem.test(x, y, g=10)
# hl
# ```
#
# where x contains the predicted values and y the actual values of one of the 5 iterations

# %%
y_pred = []
for i in ACTUAL:
  preds = []
  for j in i:
    preds.append(j[0])
  y_pred.append(preds)

# %%
prs = []
for j in range(5):
  tmp2 = []
  tmp1 = calculate_mean_probabilities(PRED[j])
  pr = get_total_predictions(tmp1, 0.5)
  prs.append(list(pr))

# %%
mydict = {"Predicted": prs[0], "Actual": y_pred[0]}
with open('data1.json', 'w') as fp:
    json.dump(str(mydict), fp)
mydict = {"Predicted": prs[1], "Actual": y_pred[1]}
with open('data2.json', 'w') as fp:
    json.dump(str(mydict), fp)
mydict = {"Predicted": prs[2], "Actual": y_pred[2]}
with open('data3.json', 'w') as fp:
    json.dump(str(mydict), fp)
mydict = {"Predicted": prs[3], "Actual": y_pred[3]}
with open('data4.json', 'w') as fp:
    json.dump(str(mydict), fp)
mydict = {"Predicted": prs[4], "Actual": y_pred[4]}
with open('data5.json', 'w') as fp:
    json.dump(str(mydict), fp)

# %% [markdown]
# # CAMBRIDGE dataset

# %% [markdown]
# ## Prepare data

# %%
csv_path = 'Cambridge_labels.csv' # path to labels csv

labels_dict_cambridge = {}
with open(csv_path) as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    for row in csv_reader:
      if row[1] == 'neg':
        labels_dict_cambridge[row[0]] = [0.0]
      elif row[1] == 'pos':
        labels_dict_cambridge[row[0]] = [1.0]

# %%
image_path = "Cambridge/Cambridge/" + transform_name + "/" # path to images
input_arr_cambridge = []
labels_arr_cambridge = []
names_arr_cambridge = []

for i in os.listdir(image_path):
  if i in labels_dict_cambridge.keys():
    image = tf.keras.preprocessing.image.load_img(image_path + i, color_mode = 'rgb', target_size = (32,32,3))
    labels_arr_cambridge.append(labels_dict_cambridge[i])
    input_arr_cambridge.append(tf.keras.preprocessing.image.img_to_array(image))
    names_arr_cambridge.append(i)

# %%
input_arr_cambridge = np.array(input_arr_cambridge)
labels_arr_cambridge = np.array(labels_arr_cambridge)

# %%
tmp = list(zip(input_arr_cambridge, labels_arr_cambridge, names_arr_cambridge))

random.Random(0).shuffle(tmp)

input_arr_cambridge, labels_arr_cambridge, names_arr_cambridge = zip(*tmp)
input_arr_cambridge = np.array(input_arr_cambridge)
labels_arr_cambridge = np.array(labels_arr_cambridge)

# %%
data_size, img_rows, img_cols, img_channels = input_arr_cambridge.shape

# %%
# we user prefetch https://www.tensorflow.org/api_docs/python/tf/data/Dataset#prefetch 
# see also AUTOTUNE
# the dataset is now "infinite"

BATCH_SIZE = 32
IMG_SHAPE = (img_rows, img_cols, img_channels)
threshold = 0.5
AUTOTUNE = tf.data.experimental.AUTOTUNE # https://www.tensorflow.org/guide/data_performance

# %% [markdown]
# ## Functions used during training and testing

# %%
def train_model(model, train_ds, validation_ds, weights, epochs = 10, steps_per_epoch = 2, validation_steps = 1):
  history = model.fit(train_ds, epochs=epochs, steps_per_epoch=steps_per_epoch, validation_data=validation_ds, validation_steps=validation_steps, class_weight = weights)
  return(history)

# %%
# plot diagnostic learning curves
def summarize_diagnostics(history):
  plt.figure(figsize=(15, 15))
  plt.suptitle('Training Curves')
  # plot loss
  
  plt.subplot(521)
  plt.title('Binary Cross Entropy Loss')
  plt.plot(history.history['loss'], color='blue', label='train')
  plt.plot(history.history['val_loss'], color='orange', label='val')
  plt.legend(loc='upper right')
  # plot accuracy
  plt.subplot(522)
  plt.title('Classification Accuracy')
  plt.plot(history.history['Accuracy'], color='blue', label='train')
  plt.plot(history.history['val_Accuracy'], color='orange', label='val')
  plt.legend(loc='lower right')
  plt.subplot(523)
  plt.title('Classification Recall')
  plt.plot(history.history['Recall'], color='blue', label='train')
  plt.plot(history.history['val_Recall'], color='orange', label='val')
  plt.legend(loc='lower right')
  plt.subplot(524)
  plt.title('Classification Precision')
  plt.plot(history.history['Precision'], color='blue', label='train')
  plt.plot(history.history['val_Precision'], color='orange', label='val')
  plt.legend(loc='lower right')
  plt.subplot(525)
  plt.title('Classification AUC')
  plt.plot(history.history['AUC'], color='blue', label='train')
  plt.plot(history.history['val_AUC'], color='orange', label='val')
  plt.legend(loc='lower right')
  return plt

# %%
def evaluate_trained_model(x_test, y_test, new_model, steps_per_epoch = 10):
    loss, recall, precision, auc, acc, tp, fp, fn, tn = new_model.evaluate(x_test, y_test, steps = steps_per_epoch)
    print('Restored model, accuracy: {:5.2f}%'.format(100 * acc))
    print('Restored model, recall: {:5.2f}%'.format(100 * recall))
    print('Restored model, precision: {:5.2f}%'.format(100 * precision))
    print('Restored model, Specificity: ', (tn/(tn+fp))*100)
    print('Restored model, AUC: {:5.2f}%'.format(100 * auc))
    
    print('Restored model, true positives: ', tp)
    print('Restored model, false positives: ', fp)
    print('Restored model, false negatives: ', fn)
    print('Restored model, true negatives: ', tn)
    
    return recall, precision, auc, acc, tp, fp, fn, tn

# %%
def get_predictions(model, x_test, y_test, threshold, steps_per_epoch):
    pred=model.predict(x_test, steps = steps_per_epoch)
    
    probabilities = []
    predictions = []
    for i in pred:
        if i[0] >= threshold:
            predictions.append(1.0)
        else:
            predictions.append(0.0)
    for i in pred:
        probabilities.append(i[0])
    
    return probabilities, predictions, pred

# %%
def print_average_results(probabilities_list, y_test, threshold):
    probabilities = calculate_mean_probabilities(probabilities_list)
    predictions = get_total_predictions(probabilities, threshold)
    (acc, recall, precision, auc, specificity)  = calculate_metrics(predictions, probabilities, y_test, threshold)
    tpr, fpr, thresholds = plot_roc(y_test, probabilities)
    return (acc, recall, precision, auc, specificity)  


def calculate_mean_probabilities(probabilities_list):
  probabilities = []
  
  for i in range(len(probabilities_list[0])):
    mean_probability = np.mean([probabilities_list[0][i], probabilities_list[1][i]])
    probabilities.append([mean_probability])
  
  probabilities = np.array(probabilities)
  return probabilities

def get_total_predictions(probabilities, threshold):
  predictions = []
  for i in probabilities:
    if i[0] >= threshold:
      predictions.append(1.0)
    elif i[0] < threshold:
      predictions.append(0.0)
  
  predictions = np.array(predictions)
  return predictions

def calculate_metrics(predictions, probabilities, y_test, threshold):
  acc = accuracy_score(y_test, predictions)*100
  recall = recall_score(y_test, predictions, zero_division = 0)*100
  precision  = precision_score(y_test, predictions, zero_division = 0)*100
  auc = roc_auc_score(y_test, probabilities)*100
  tn, fp, fn, tp = confusion_matrix(y_test, predictions).ravel()
  specificity = tn / (tn+fp)
  print("Accuracy: ", acc, "%")
  print("Recall: ", recall, "%")
  print("Precision: ",precision, "%")
  print("AUC: ",auc, "%")
  print("Specificity: ", specificity*100, "%")

  return (acc, recall, precision, auc, specificity*100)

# %%
# Plot ROC curve

def plot_roc(y_true, probabilities):
    y_true_int = []
    for i in y_true:
        y_true_int.append(int(i))

    # calculate roc curves
    fpr, tpr, thresholds = roc_curve(y_true_int, probabilities)
    # plot the roc curve for the model
    plt.subplot(526)
    plt.plot([0,1], [0,1], linestyle='--', label='No Skill')
    plt.plot(fpr, tpr, marker='.', label='CNN Model')
    # axis labels
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend()
    # show the plot
    plt.show()
    print(roc_auc_score(y_true_int, probabilities), "AUC")
    return tpr, fpr, thresholds

# %%
def calculate_weights(y_train):
    no_neg = 0
    no_pos = 0
    for i in y_train:
        if i[0] == 0.0:
            no_neg = no_neg + 1
        else:
            no_pos = no_pos + 1
    print("Train set in use: Number of negatives:", no_neg, "|| Number of positives:", no_pos)

    ratio = (no_pos*100)/(no_neg+no_pos)
    w_0 = ratio
    w_1 = 100-ratio
    print("w_0:", w_0)
    print("w_1:", w_1)

    # Give class weights
    class_weight = {0: w_0,
                    1: w_1}
    return class_weight

# %%
def _input_fn(x, y, BATCH_SIZE, data_size, IMG_SIZE): ### to data size prostethike meta

  x_reshaped = []
  print(x.shape)
  for i in x:
    x_reshaped.append(tf.image.resize(i, IMG_SIZE))
  x_reshaped = np.array(x_reshaped)
  print(x_reshaped.shape)
  ds = tf.data.Dataset.from_tensor_slices((x_reshaped,y)) 
  ds = ds.shuffle(buffer_size=data_size) # https://datascience.stackexchange.com/questions/89316/tensorflows-shufflebuffer-size
  ds = ds.repeat() # https://stackoverflow.com/questions/53514495/what-does-batch-repeat-and-shuffle-do-with-tensorflow-dataset
  ds = ds.batch(BATCH_SIZE)
  ds = ds.prefetch(buffer_size=AUTOTUNE)
  return ds

# %%
def ensemble_split(x_train, y_train):
  neg = 0
  pos = 0

  x_train_set = []
  y_train_set = []

  tmp_1x = []
  tmp_2x = []

  tmp_1y = []
  tmp_2y = []

  tmp_x = []
  tmp_y = []
  
  for i in y_train:
    if i[0] == 0.0:
      neg = neg + 1
    else:
      pos = pos + 1

  print("Initial train set contains", pos, "covid samples and", neg, "non-covid samples")
  neg_samples = round(neg/2)

  train_neg = []
  train_pos = []
  index = 0

  for i in y_train:
    if i[0] == 0.0:
      train_neg.append(index)
    elif i[0] == 1.0:
      train_pos.append(index)
    index = index + 1
  
  index_1 = train_neg[0:neg_samples]
  index_2 = train_neg[neg_samples:]

  for i in index_1:
    tmp_1x.append(x_train[i])
    tmp_1y.append(y_train[i])

  for i in index_2:
    tmp_2x.append(x_train[i])
    tmp_2y.append(y_train[i])
  
  for i in train_pos:
    tmp_x.append(x_train[i])
    tmp_y.append(y_train[i])

  tmp_x = np.array(tmp_x)
  tmp_y  = np.array(tmp_y)

  tmp_1x = np.array(tmp_1x)
  tmp_2x = np.array(tmp_2x)

  tmp_1y = np.array(tmp_1y)
  tmp_2y = np.array(tmp_2y)

  x_train_set.append(np.concatenate((tmp_1x,tmp_x), axis = 0))
  x_train_set.append(np.concatenate((tmp_2x,tmp_x), axis = 0))

  y_train_set.append(np.concatenate((tmp_1y,tmp_y), axis = 0))
  y_train_set.append(np.concatenate((tmp_2y,tmp_y), axis = 0))

  return x_train_set, y_train_set

# %%
def train_with_5_folds_ensemble(splitted_folds):
  PROBABILITIES_LIST = []
  PREDICTIONS_LIST = []
  ACCURACY = []
  RECALL = []
  PRECISION = []
  AUC = []
  SPECIFICITY = []
  ACTUAL = []
  PREDICTIONS = []
  new_m = []
  j = 0

  for fold in splitted_folds:

    X_train = []
    X_val = []
    X_test = []

    y_train = []
    y_val = []
    y_test = []


    for files in fold[0]:
      X_train.append(input_arr_cambridge[files]/255.0)
      y_train.append(labels_arr_cambridge[files])
    for files in fold[1]:
      X_val.append(input_arr_cambridge[files]/255.0)
      y_val.append(labels_arr_cambridge[files])
    for files in fold[2]:
      X_test.append(input_arr_cambridge[files]/255.0)
      y_test.append(labels_arr_cambridge[files])


    print("Initial train set", len(X_train), len(y_train))
    print("Initial validation set", len(X_val), len(y_val))
    print("Initial test set", len(X_test), len(y_test))
    
    X_train = np.array(X_train)
    X_val = np.array(X_val)
    X_test = np.array(X_test)

    y_train = np.array(y_train)
    y_val = np.array(y_val)
    y_test = np.array(y_test)

    neg = 0 
    pos = 0
    for i in y_test:
      if i[0] == 1.0:
        pos = pos + 1
      elif i[0] == 0.0:
        neg = neg + 1

    print("Initial test set: Negative samples:", neg, "|| Positive samples:", pos, "|| Total_samples:", neg+pos) 

    neg = 0 
    pos = 0
    for i in y_val:
      if i[0] == 1.0:
        pos = pos + 1
      elif i[0] == 0.0:
        neg = neg + 1

    print("Initial validation set: Negative samples:", neg, "|| Positive samples:", pos, "|| Total_samples:", neg+pos)

    (PRED, test, acc, recall, precision, auc, specificity, m) = train_with_ensemble(X_train, y_train, X_val, y_val, X_test, y_test)
    new_m.append(m)
    j = j + 1
    RECALL.append(recall)
    PRECISION.append(precision)
    AUC.append(auc)
    ACCURACY.append(acc)
    SPECIFICITY.append(specificity)
    PREDICTIONS.append(PRED)
    ACTUAL.append(test)


  print("Accuracy:", round(np.mean(ACCURACY),4), "%")
  print("Recall:", round(np.mean(RECALL),4), "%")
  print("Precision:", round(np.mean(PRECISION),4), "%")
  print("AUC:", round(np.mean(AUC),4), "%")
  print("Specificity:", round(np.mean(SPECIFICITY),4), "%")

  return PREDICTIONS, ACTUAL

# %%
def train_with_ensemble(X_train, y_train, X_val, y_val, X_test, y_test):
    img = 100
    IMG_SHAPE = (img, img, 3)
    new_models = []
    validation_ds =_input_fn(X_val,y_val, BATCH_SIZE, data_size, (img,img)) #PrefetchDataset object

    test_ds =_input_fn(X_test, y_test, BATCH_SIZE, data_size, (img,img)) #PrefetchDataset object

    x_train_set, y_train_set = ensemble_split(X_train, y_train)

    x_reshaped = []
    for i in X_test:
      x_reshaped.append(tf.image.resize(i, (img, img)))
    x_reshaped = np.array(x_reshaped)

    PROBABILITIES_LIST = []
    PREDICTIONS_LIST = []
    for i in range(len(x_train_set)):
      weights = calculate_weights(y_train_set[i])

      test_steps = int(len(y_test)/BATCH_SIZE)
      train_ds =_input_fn(x_train_set[i], y_train_set[i], BATCH_SIZE, data_size, (img,img)) #PrefetchDataset object
      
      model = init_model_2(True, IMG_SHAPE)
      model_history = train_model(model, train_ds, validation_ds, weights, 30, int(len(y_train_set[i])/BATCH_SIZE), 10)
    
      summarize_diagnostics(model_history)

      recall, precision, auc, acc, tp, fp, fn, tn = evaluate_trained_model(x_reshaped, y_test, model, steps_per_epoch = test_steps)
      
      probabilities, predictions, pred = get_predictions(model, x_reshaped, y_test, threshold, test_steps)

      PROBABILITIES_LIST.append(probabilities)
      PREDICTIONS_LIST.append(predictions)
      new_models.append(model)
      
    (acc, recall, precision, auc, specificity) = print_average_results(PROBABILITIES_LIST, y_test, threshold)
    print()

    print("-------------------------------------------------------------------------------------------------------------------------------------------")
    print("-------------------------------------------------------------------------------------------------------------------------------------------")
    return (PROBABILITIES_LIST, y_test, acc, recall, precision, auc,specificity, new_models)

# %%
def folds_split_Cambridge_stratified():
  folds_split = 0.2

  folds = [[], [], [], [], []]

  ###folds contain indices
  ind_flag = [0] * len(names_arr_cambridge)

  cnt = 0 
  x = folds_split

  non_covid = 0
  covid = 0

  for file in labels_arr_cambridge:
    if file == [0.0]:
      non_covid = non_covid + 1
    else:
      covid = covid + 1

  non_covid_percentage = non_covid/(covid + non_covid)
  covid_percentage = covid/(covid + non_covid)

  print("Non covid percentage:", non_covid_percentage)
  print("Covid percentage:", covid_percentage)


  for i in range(5):
    neg = 0
    pos = 0
    while len(folds[i]) < folds_split*data_size :
      for ind in range(data_size):
        if ind_flag[ind] == 0:
          if len(names_arr_cambridge[ind].split("_")) ==  3: # ---> android files' format (only android files have many samples from the same user)
            indices = [j for j, s in enumerate(names_arr_cambridge) if names_arr_cambridge[ind].split(".")[0].split("_")[1] in s]
            if i!=4 and (labels_arr_cambridge[ind] == [0.0] and neg<=non_covid_percentage*folds_split*data_size) or (labels_arr_cambridge[ind] == [1.0] and pos<=covid_percentage*folds_split*data_size):
              for inds in indices:
                
                if labels_arr_cambridge[inds] == [0.0]:
                  neg = neg + 1
                else:
                  pos = pos + 1
                
                folds[i].append(inds)
                ind_flag[inds] = 1
              cnt = cnt + len(indices)
            elif i==4 :
              for inds in indices:
                
                if labels_arr_cambridge[inds] == [0.0]:
                  neg = neg + 1
                else:
                  pos = pos + 1
                
                folds[i].append(inds)
                ind_flag[inds] = 1
              cnt = cnt + len(indices)

            else:
              continue
          else:
            
            indices = [j for j, s in enumerate(names_arr_cambridge) if names_arr_cambridge[ind].split(".")[0].split("_")[1] + "_" + names_arr_cambridge[ind].split(".")[0].split("_")[2] + "_" + names_arr_cambridge[ind].split(".")[0].split("_")[3] + "_" + names_arr_cambridge[ind].split(".")[0].split("_")[4] in s]

            if i!=4 and (labels_arr_cambridge[ind] == [0.0] and neg<=non_covid_percentage*folds_split*data_size) or (labels_arr_cambridge[ind] == [1.0] and pos<=covid_percentage*folds_split*data_size):
              for inds in indices:
                
                if labels_arr_cambridge[inds] == [0.0]:
                  neg = neg + 1
                else:
                  pos = pos + 1
                folds[i].append(inds)
                ind_flag[inds] = 1
              cnt = cnt + len(indices)
            elif i==4:
              
              for inds in indices:
                
                if labels_arr_cambridge[inds] == [0.0]:
                  neg = neg + 1
                else:
                  pos = pos + 1
                folds[i].append(inds)
                ind_flag[inds] = 1
              cnt = cnt + len(indices)
            else:
              continue

        if len(folds[i]) >= folds_split*data_size:
          break
      if i == 4 and cnt == data_size:
        break
    
  return folds

# %% [markdown]
# ## Training and testing

# %%
folds = folds_split_Cambridge_stratified()
# Out:
# Non covid percentage: 0.69
# Covid percentage: 0.31

# %%
for f in folds:
  neg = 0
  pos = 0
  for ff in f:
    if labels_arr_cambridge[ff] == [0.0]:
      neg = neg + 1
    else:
      pos =pos + 1
  print("Negative:", neg/(neg+pos), "positive:", pos/(neg+pos))
  print("-------------------------------------------------------")
# Out:
# Negative: 0.6829268292682927 positive: 0.3170731707317073
# -------------------------------------------------------
# Negative: 0.6625 positive: 0.3375
# -------------------------------------------------------
# Negative: 0.6 positive: 0.4
# -------------------------------------------------------
# Negative: 0.7 positive: 0.3
# -------------------------------------------------------
# Negative: 0.8076923076923077 positive: 0.19230769230769232
# -------------------------------------------------------

# %%
for f in folds[0]:
  if f in folds[1] or f in folds[2] or f in folds[3] or f in folds[4]:
    print("The same sample exists in more than one folds")

for f in folds[1]:
  if f in folds[0] or f in folds[2] or f in folds[3] or f in folds[4]:
    print("The same sample exists in more than one folds")

for f in folds[2]:
  if f in folds[0] or f in folds[1] or f in folds[3] or f in folds[4]:
    print("The same sample exists in more than one folds")

for f in folds[3]:
  if f in folds[0] or f in folds[1] or f in folds[2] or f in folds[4]:
    print("The same sample exists in more than one folds")

for f in folds[4]:
  if f in folds[0] or f in folds[1] or f in folds[2] or f in folds[3]:
    print("The same sample exists in more than one folds")

# %%
# concatenate folds to create 5 different splits of the dataset into train, validation and test set

tmp = []
splitted_folds = []
for i in range(len(folds)):
  print(len(folds[i]))

tmp.append(list(folds[1]+folds[2]+folds[3])) # train
tmp.append(folds[4]) # validation
tmp.append(list(folds[0])) # test
splitted_folds.append(list(tmp))
tmp = []

tmp.append(list(folds[0]+folds[2]+folds[4]))
tmp.append(folds[3])
tmp.append(list(folds[1]))
splitted_folds.append(list(tmp))
tmp = []

tmp.append(list(folds[0]+folds[3]+folds[4]))
tmp.append(folds[1])
tmp.append(list(folds[2]))
splitted_folds.append(list(tmp))
tmp = []

tmp.append(list(folds[1]+folds[2]+folds[4]))
tmp.append(folds[0])
tmp.append(list(folds[3]))
splitted_folds.append(list(tmp))
tmp = []

tmp.append(list(folds[0]+folds[1]+folds[3]))
tmp.append(folds[2])
tmp.append(list(folds[4]))
splitted_folds.append(list(tmp))
# Out:
# 82
# 80
# 80
# 80
# 78

# %%
for f in splitted_folds:
  print("Train set contains", len(f[0]), "samples, validation set contains", len(f[1]), "samples, test set contains", len(f[2]), "samples")
# Out:
# Train set contains 240 samples, validation set contains 78 samples, test set contains 82 samples
# Train set contains 240 samples, validation set contains 80 samples, test set contains 80 samples
# Train set contains 240 samples, validation set contains 80 samples, test set contains 80 samples
# Train set contains 238 samples, validation set contains 82 samples, test set contains 80 samples
# Train set contains 242 samples, validation set contains 80 samples, test set contains 78 samples

# %%
# statistics for each fold

for ff in folds:
  neg = 0
  pos = 0
  for i in ff:
    if labels_arr_cambridge[i] == [0.0]:
      neg = neg + 1
    else:
      pos = pos + 1
  print("Negative:", neg, "total", pos+neg, "Percentage:", (neg*100)/(neg+pos))
  print("Positive:", pos, "total", pos+neg, "Percentage:", (pos*100)/(neg+pos))
  print("------------------------------------------------------------------------")
# Out:
# Negative: 56 total 82 Percentage: 68.29268292682927
# Positive: 26 total 82 Percentage: 31.70731707317073
# ------------------------------------------------------------------------
# Negative: 53 total 80 Percentage: 66.25
# Positive: 27 total 80 Percentage: 33.75
# ------------------------------------------------------------------------
# Negative: 48 total 80 Percentage: 60.0
# Positive: 32 total 80 Percentage: 40.0
# ------------------------------------------------------------------------
# Negative: 56 total 80 Percentage: 70.0
# Positive: 24 total 80 Percentage: 30.0
# ------------------------------------------------------------------------
# Negative: 63 total 78 Percentage: 80.76923076923077
# Positive: 15 total 78 Percentage: 19.23076923076923
# ------------------------------------------------------------------------

# %%
threshold = 0.5
PRED, ACTUAL = train_with_5_folds_ensemble(splitted_folds)
# Out:
# Initial train set 240 240
# Initial validation set 78 78
# Initial test set 82 82
# Initial test set: Negative samples: 56 || Positive samples: 26 || Total_samples: 82
# Initial validation set: Negative samples: 63 || Positive samples: 15 || Total_samples: 78
# (78, 32, 32, 3)
# (78, 100, 100, 3)
# (82, 32, 32, 3)
# (82, 100, 100, 3)
# Initial train set contains 83 covid samples and 157 non-covid samples
# Train set in use: Number of negatives: 78 || Number of positives: 83
# w_0: 51.5527950310559
# w_1: 48.4472049689441
# (161, 32, 32, 3)
# (161, 100, 100, 3)
# Model: "sequential_65"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_195 (Conv2D)          (None, 96, 96, 4)         304
# _________________________________________________________________
# dropout_260 (Dropout)        (None, 96, 96, 4)         0
# _________________________________________________________________
# average_pooling2d_130 (Avera (None, 48, 48, 4)         0
# _________________________________________________________________
# conv2d_196 (Conv2D)          (None, 44, 44, 16)        1616
# _________________________________________________________________
# dropout_261 (Dropout)        (None, 44, 44, 16)        0
# _________________________________________________________________
# average_pooling2d_131 (Avera (None, 22, 22, 16)        0
# _________________________________________________________________
# conv2d_197 (Conv2D)          (None, 18, 18, 32)        12832
# _________________________________________________________________
# dropout_262 (Dropout)        (None, 18, 18, 32)        0
# _________________________________________________________________
# flatten_65 (Flatten)         (None, 10368)             0
# _________________________________________________________________
# dropout_263 (Dropout)        (None, 10368)             0
# _________________________________________________________________
# dense_65 (Dense)             (None, 1)                 10369
# =================================================================
# Total params: 25,121
# Trainable params: 25,121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] - 3s
# 5/5 [==============================] - 0s 44ms/step - loss: 31.7591 - Recall: 0.6420 - Precision: 0.6667 - AUC: 0.7035 - Accuracy: 0.6562 - true_positives_65: 52.0000 - false_positives_65: 26.0000 - false_negatives_65: 29.0000 - true_negatives_65: 53.0000 - val_loss: 0.6631 - val_Recall: 0.5873 - val_Precision: 0.2913 - val_AUC: 0.6558 - val_Accuracy: 0.6375 - val_true_positives_65: 37.0000 - val_false_positives_65: 90.0000 - val_false_negatives_65: 26.0000 - val_true_negatives_65: 167.0000
# Epoch 29/30
# 5/5 [==============================] - 0s 48ms/step - loss: 30.0948 - Recall: 0.7229 - Precision: 0.6818 - AUC: 0.7709 - Accuracy: 0.6812 - true_positives_65: 60.0000 - false_positives_65: 28.0000 - false_negatives_65: 23.0000 - true_negatives_65: 49.0000 - val_loss: 0.6334 - val_Recall: 0.6066 - val_Precision: 0.3246 - val_AUC: 0.6704 - val_Accuracy: 0.6844 - val_true_positives_65: 37.0000 - val_false_positives_65: 77.0000 - val_false_negatives_65: 24.0000 - val_true_negatives_65: 182.0000
# Epoch 30/30
# 5/5 [==============================] - 0s 47ms/step - loss: 32.8201 - Recall: 0.5060 - Precision: 0.6562 - AUC: 0.6659 - Accuracy: 0.6062 - true_positives_65: 42.0000 - false_positives_65: 22.0000 - false_negatives_65: 41.0000 - true_negatives_65: 55.0000 - val_loss: 0.6383 - val_Recall: 0.5968 - val_Precision: 0.3217 - val_AUC: 0.6616 - val_Accuracy: 0.6781 - val_true_positives_65: 37.0000 - val_false_positives_65: 78.0000 - val_false_negatives_65: 25.0000 - val_true_negatives_65: 180.0000
# 2/2 [==============================] - 1s 17ms/step - loss: 0.6843 - Recall: 0.8462 - Precision: 0.4074 - AUC: 0.6635 - Accuracy: 0.5610 - true_positives_65: 22.0000 - false_positives_65: 32.0000 - false_negatives_65: 4.0000 - true_negatives_65: 24.0000
# Restored model, accuracy: 56.10%
# Restored model, recall: 84.62%
# Restored model, precision: 40.74%
# Restored model, Specificity:  42.857142857142854
# Restored model, AUC: 66.35%
# Restored model, true positives:  22.0
# Restored model, false positives:  32.0
# Restored model, false negatives:  4.0
# Restored model, true negatives:  24.0
# WARNING:tensorflow:6 out of the last 26 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fd54f46cf80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Train set in use: Number of negatives: 79 || Number of positives: 83
# w_0: 51.23456790123457
# w_1: 48.76543209876543
# (162, 32, 32, 3)
# (162, 100, 100, 3)
# Model: "sequential_66"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_198 (Conv2D)          (None, 96, 96, 4)         304
# _________________________________________________________________
# dropout_264 (Dropout)        (None, 96, 96, 4)         0
# _________________________________________________________________
# average_pooling2d_132 (Avera (None, 48, 48, 4)         0
# _________________________________________________________________
# conv2d_199 (Conv2D)          (None, 44, 44, 16)        1616
# _________________________________________________________________
# dropout_265 (Dropout)        (None, 44, 44, 16)        0
# _________________________________________________________________
# average_pooling2d_133 (Avera (None, 22, 22, 16)        0
# _________________________________________________________________
# conv2d_200 (Conv2D)          (None, 18, 18, 32)        12832
# _________________________________________________________________
# dropout_266 (Dropout)        (None, 18, 18, 32)        0
# _________________________________________________________________
# flatten_66 (Flatten)         (None, 10368)             0
# _________________________________________________________________
# dropout_267 (Dropout)        (None, 10368)             0
# _________________________________________________________________
# dense_66 (Dense)             (None, 1)                 10369
# =================================================================
# Total params: 25,121
# Trainable params: 25,121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 5/5 [==============================] -
# 5/5 [==============================] - 0s 47ms/step - loss: 30.0634 - Recall: 0.5802 - Precision: 0.6438 - AUC: 0.7282 - Accuracy: 0.6250 - true_positives_66: 47.0000 - false_positives_66: 26.0000 - false_negatives_66: 34.0000 - true_negatives_66: 53.0000 - val_loss: 0.7143 - val_Recall: 0.8689 - val_Precision: 0.3064 - val_AUC: 0.7059 - val_Accuracy: 0.6000 - val_true_positives_66: 53.0000 - val_false_positives_66: 120.0000 - val_false_negatives_66: 8.0000 - val_true_negatives_66: 139.0000
# Epoch 29/30
# 5/5 [==============================] - 0s 45ms/step - loss: 28.7140 - Recall: 0.7381 - Precision: 0.7045 - AUC: 0.7770 - Accuracy: 0.7000 - true_positives_66: 62.0000 - false_positives_66: 26.0000 - false_negatives_66: 22.0000 - true_negatives_66: 50.0000 - val_loss: 0.7084 - val_Recall: 0.8033 - val_Precision: 0.2988 - val_AUC: 0.7049 - val_Accuracy: 0.6031 - val_true_positives_66: 49.0000 - val_false_positives_66: 115.0000 - val_false_negatives_66: 12.0000 - val_true_negatives_66: 144.0000
# Epoch 30/30
# 5/5 [==============================] - 0s 46ms/step - loss: 27.1579 - Recall: 0.7614 - Precision: 0.7976 - AUC: 0.8098 - Accuracy: 0.7625 - true_positives_66: 67.0000 - false_positives_66: 17.0000 - false_negatives_66: 21.0000 - true_negatives_66: 55.0000 - val_loss: 0.7134 - val_Recall: 0.7879 - val_Precision: 0.3171 - val_AUC: 0.6964 - val_Accuracy: 0.6062 - val_true_positives_66: 52.0000 - val_false_positives_66: 112.0000 - val_false_negatives_66: 14.0000 - val_true_negatives_66: 142.0000
# 2/2 [==============================] - 1s 21ms/step - loss: 0.7132 - Recall: 1.0000 - Precision: 0.4333 - AUC: 0.7730 - Accuracy: 0.5854 - true_positives_66: 26.0000 - false_positives_66: 34.0000 - false_negatives_66: 0.0000e+00 - true_negatives_66: 22.0000
# Restored model, accuracy: 58.54%
# Restored model, recall: 100.00%
# Restored model, precision: 43.33%
# Restored model, Specificity:  39.285714285714285
# Restored model, AUC: 77.30%
# Restored model, true positives:  26.0
# Restored model, false positives:  34.0
# Restored model, false negatives:  0.0
# Restored model, true negatives:  22.0
# Accuracy:  59.756097560975604 %
# Recall:  92.3076923076923 %
# Precision:  43.63636363636363 %
# AUC:  72.52747252747254 %
# Specificity:  44.642857142857146 %
# 0.7252747252747254 AUC
# Best Threshold=0.474062, G-Mean=1.393
#
# -------------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------------
# Initial train set 240 240
# Initial validation set 80 80
# Initial test set 80 80
# Initial test set: Negative samples: 53 || Positive samples: 27 || Total_samples: 80
# Initial validation set: Negative samples: 56 || Positive samples: 24 || Total_samples: 80
# (80, 32, 32, 3)
# (80, 100, 100, 3)
# (80, 32, 32, 3)
# (80, 100, 100, 3)
# Initial train set contains 73 covid samples and 167 non-covid samples
# Train set in use: Number of negatives: 84 || Number of positives: 73
# w_0: 46.496815286624205
# w_1: 53.503184713375795
# (157, 32, 32, 3)
# (157, 100, 100, 3)
# Model: "sequential_67"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_201 (Conv2D)          (None, 96, 96, 4)         304
# _________________________________________________________________
# dropout_268 (Dropout)        (None, 96, 96, 4)         0
# _________________________________________________________________
# average_pooling2d_134 (Avera (None, 48, 48, 4)         0
# _________________________________________________________________
# conv2d_202 (Conv2D)          (None, 44, 44, 16)        1616
# _________________________________________________________________
# dropout_269 (Dropout)        (None, 44, 44, 16)        0
# _________________________________________________________________
# average_pooling2d_135 (Avera (None, 22, 22, 16)        0
# _________________________________________________________________
# conv2d_203 (Conv2D)          (None, 18, 18, 32)        12832
# _________________________________________________________________
# dropout_270 (Dropout)        (None, 18, 18, 32)        0
# _________________________________________________________________
# flatten_67 (Flatten)         (None, 10368)             0
# _________________________________________________________________
# dropout_271 (Dropout)        (None, 10368)             0
# _________________________________________________________________
# dense_67 (Dense)             (None, 1)                 10369
# =================================================================
# Total params: 25,121
# Trainable params: 25,121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 4/4 [==============================] - 3s 347ms/step - loss: 34.1366 - Recall: 0.0556 - Precision: 0.7500 - AUC: 0.5269 - Accuracy: 0.5938 - true_positives_67: 3.0000 - false_positives_67: 1.0000 - false_negatives_67: 51.0000 - true_negatives_67: 73.0000 - val_loss: 0.6840 - val_Recall: 0.0000e+00 - val_Precision: 0.0000e+00 - val_AUC: 0.5577 - val_Accuracy: 0.7000 - val_true_positives_67: 0.0000e+00 - val_false_positives_67: 0.0000e+00 - val_false_negatives_67: 96.0000 - val_true_negatives_67: 224.0000
# Epoch 2/30
# 4/4 [==============================] - 0s 57ms/step - loss: 34.2287 - Recall: 0.1207 - Precision: 0.7000 - AUC: 0.6132 - Accuracy: 0.5781 - true_positives_67: 7.0000 - false_positives_67: 3.0000 - false_negatives_67: 51.0000 - true_negatives_67: 67.0000 - val_loss: 0.6826 - val_Recall: 0.0000e+00 - val_Precision: 0.0000e+00 - val_AUC: 0.5833 - val_Accuracy: 0.7000 - val_true_positives_67: 0.0000e+00 - val_false_positives_67: 0.0000e+00 - val_false_negatives_67: 96.0000 - val_true_negatives_67: 224.0000
# Epoch 3/30
# 4/4 [==============================] - 0s 54ms/step - loss: 34.8648 - Recall: 0.0597 - Precision: 0.5000 - AUC: 0.5439 - Accuracy: 0.4766 - true_positives_67: 4.0000 - false_positives_67: 4.0000 - false_negatives_67: 63.0000 - true_negatives_67: 57.0000 - val_loss: 0.6828 - val_Recall: 0.0000e+00 - val_Precision: 0.0000e+00 - val_AUC: 0.5487 - val_Accuracy: 0.7000 - val_true_positives_67: 0.0000e+00 - val_false_positives_67: 0.0000e+00 - val_false_negatives_67: 96.0000 - val_true_negatives_67: 224.0000
# Epoch 4/30
# 4/4 [==============================] - 0s 59ms/step - loss: 34.4632 - Recall: 0.0690 - Precision: 0.4444 - AUC: 0.4793 - Accuracy: 0.5391 - true_positives_67: 4.0000 - false_positives_67: 5.0000 - false_negatives_67: 54.0000 - true_negatives_67: 65.0000 - val_loss: 0.6829 - val_Recall: 0.0000e+00 - val_Precision: 0.0000e+00 - val_AUC: 0.6310 - val_Accuracy: 0.7000 - val_true_positives_67: 0.0000e+00 - val_false_positives_67: 0.0000e+00 - val_false_negatives_67: 96.0000 - val_true_negatives_67: 224.0000
# Epoch 5/30
# 4/4 [==============================] - 0s 53ms/step - loss: 34.5263 - Recall: 0.0484 - Precision: 0.5000 - AUC: 0.5836 - Accuracy: 0.5156 - true_positives_67: 3.0000 - false_positives_67: 3.0000 - false_negatives_67: 59.0000 - true_negatives_67: 63.0000 - val_loss: 0.6828 - val_Recall: 0.0000e+00 - val_Precision: 0.0000e+00 - val_AUC: 0.6310 - val_Accuracy: 0.7000 - val_true_positives_67: 0.0000e+00 - val_false_positives_67: 0.0000e+00 - val_false_negatives_67: 96.0000 - val_true_negatives_67: 224.0000
# Epoch 6/30
# 4/4 [==============================] - 0s 55ms/step - loss: 34.1606 - Recall: 0.2069 - Precision: 0.5714 - AUC: 0.6587 - Accuracy: 0.5703 - true_positives_67: 12.0000 - false_positives_67: 9.0000 - false_negatives_67: 46.0000 - true_negatives_67: 61.0000 - val_loss: 0.6824 - val_Recall: 0.0417 - val_Precision: 0.5000 - val_AUC: 0.6068 - val_Accuracy: 0.7000 - val_true_positives_67: 4.0000 - val_false_positives_67: 4.0000 - val_false_negatives_67: 92.0000 - val_true_negatives_67: 220.0000
# Epoch 7/30
# 4/4 [==============================] - 0s 75ms/step - loss: 34.6130 - Recall: 0.2031 - Precision: 0.5200 - AUC: 0.5747 - Accuracy: 0.5078 - true_positives_67: 13.0000 - false_positives_67: 12.0000 - false_negatives_67: 51.0000 - true_negatives_67: 52.0000 - val_loss: 0.6823 - val_Recall: 0.0417 - val_Precision: 0.3333 - val_AUC: 0.6313 - val_Accuracy: 0.6875 - val_true_positives_67: 4.0000 - val_false_positives_67: 8.0000 - val_false_negatives_67: 92.0000 - val_true_negatives_67: 216.0000
# Epoch 8/30
# 4/4 [==============================] - 0s 59ms/step - loss: 33.7638 - Recall: 0.2778 - Precision: 0.7500 - AUC: 0.7216 - Accuracy: 0.6562 - true_positives_67: 15.0000 - false_positives_67: 5.0000 - false_negatives_67: 39.0000 - true_negatives_67: 69.0000 - val_loss: 0.6815 - val_Recall: 0.1667 - val_Precision: 0.6667 - val_AUC: 0.6518 - val_Accuracy: 0.7250 - val_true_positives_67: 16.0000 - val_false_positives_67: 8.0000 - val_false_negatives_67: 80.0000 - val_true_negatives_67: 216.0000
# Epoch 9/30
# 4/4 [==============================] - 0s 56ms/step - loss: 34.2498 - Recall: 0.3651 - Precision: 0.7419 - AUC: 0.6864 - Accuracy: 0.6250 - true_positives_67: 23.0000 - false_positives_67: 8.0000 - false_negatives_67: 40.0000 - true_negatives_67: 57.0000 - val_loss: 0.6808 - val_Recall: 0.2500 - val_Precision: 0.6000 - val_AUC: 0.6440 - val_Accuracy: 0.7250 - val_true_positives_67: 24.0000 - val_false_positives_67: 16.0000 - val_false_negatives_67: 72.0000 - val_true_negatives_67: 208.0000
# Epoch 10/30
# 4/4 [==============================] - 0s 59ms/step - loss: 34.0718 - Recall: 0.3793 - Precision: 0.6875 - AUC: 0.6667 - Accuracy: 0.6406 - true_positives_67: 22.0000 - false_positives_67: 10.0000 - false_negatives_67: 36.0000 - true_negatives_67: 60.0000 - val_loss: 0.6795 - val_Recall: 0.2500 - val_Precision: 0.6000 - val_AUC: 0.6540 - val_Accuracy: 0.7250 - val_true_positives_67: 24.0000 - val_false_positives_67: 16.0000 - val_false_negatives_67: 72.0000 - val_true_negatives_67: 208.0000
# Epoch 11/30
# 4/4 [==============================] - 0s 58ms/step - loss: 33.7649 - Recall: 0.4576 - Precision: 0.7500 - AUC: 0.7454 - Accuracy: 0.6797 - true_positives_67: 27.0000 - false_positives_67: 9.0000 - false_negatives_67: 32.0000 - true_negatives_67: 60.0000 - val_loss: 0.6785 - val_Recall: 0.2500 - val_Precision: 0.4615 - val_AUC: 0.6525 - val_Accuracy: 0.6875 - val_true_positives_67: 24.0000 - val_false_positives_67: 28.0000 - val_false_negatives_67: 72.0000 - val_true_negatives_67: 196.0000
# Epoch 12/30
# 4/4 [==============================] - 0s 58ms/step - loss: 33.3400 - Recall: 0.5556 - Precision: 0.7143 - AUC: 0.7865 - Accuracy: 0.7188 - true_positives_67: 30.0000 - false_positives_67: 12.0000 - false_negatives_67: 24.0000 - true_negatives_67: 62.0000 - val_loss: 0.6757 - val_Recall: 0.2500 - val_Precision: 0.4000 - val_AUC: 0.6507 - val_Accuracy: 0.6625 - val_true_positives_67: 24.0000 - val_false_positives_67: 36.0000 - val_false_negatives_67: 72.0000 - val_true_negatives_67: 188.0000
# Epoch 13/30
# 4/4 [==============================] - 0s 53ms/step - loss: 33.7327 - Recall: 0.5082 - Precision: 0.6739 - AUC: 0.7070 - Accuracy: 0.6484 - true_positives_67: 31.0000 - false_positives_67: 15.0000 - false_negatives_67: 30.0000 - true_negatives_67: 52.0000 - val_loss: 0.6740 - val_Recall: 0.3750 - val_Precision: 0.4737 - val_AUC: 0.6499 - val_Accuracy: 0.6875 - val_true_positives_67: 36.0000 - val_false_positives_67: 40.0000 - val_false_negatives_67: 60.0000 - val_true_negatives_67: 184.0000
# Epoch 14/30
# 4/4 [==============================] - 0s 57ms/step - loss: 34.2746 - Recall: 0.5000 - Precision: 0.6604 - AUC: 0.6787 - Accuracy: 0.5859 - true_positives_67: 35.0000 - false_positives_67: 18.0000 - false_negatives_67: 35.0000 - true_negatives_67: 40.0000 - val_loss: 0.6726 - val_Recall: 0.5000 - val_Precision: 0.4615 - val_AUC: 0.6592 - val_Accuracy: 0.6750 - val_true_positives_67: 48.0000 - val_false_positives_67: 56.0000 - val_false_negatives_67: 48.0000 - val_true_negatives_67: 168.0000
# Epoch 15/30
# 4/4 [==============================] - 0s 56ms/step - loss: 33.1283 - Recall: 0.6000 - Precision: 0.6735 - AUC: 0.7219 - Accuracy: 0.7031 - true_positives_67: 33.0000 - false_positives_67: 16.0000 - false_negatives_67: 22.0000 - true_negatives_67: 57.0000 - val_loss: 0.6703 - val_Recall: 0.5000 - val_Precision: 0.4286 - val_AUC: 0.6562 - val_Accuracy: 0.6500 - val_true_positives_67: 48.0000 - val_false_positives_67: 64.0000 - val_false_negatives_67: 48.0000 - val_true_negatives_67: 160.0000
# Epoch 30/30
# 5/5 [==============================] - 0s 48ms/step - loss: 27.9821 - Recall: 0.7403 - Precision: 0.7037 - AUC: 0.7796 - Accuracy: 0.7250 - true_positives_74: 57.0000 - false_positives_74: 24.0000 - false_negatives_74: 20.0000 - true_negatives_74: 59.0000 - val_loss: 0.6310 - val_Recall: 0.5000 - val_Precision: 0.6154 - val_AUC: 0.6839 - val_Accuracy: 0.6750 - val_true_positives_74: 64.0000 - val_false_positives_74: 40.0000 - val_false_negatives_74: 64.0000 - val_true_negatives_74: 152.0000
# 2/2 [==============================] - 1s 28ms/step - loss: 0.6114 - Recall: 0.6000 - Precision: 0.3214 - AUC: 0.6593 - Accuracy: 0.6795 - true_positives_74: 9.0000 - false_positives_74: 19.0000 - false_negatives_74: 6.0000 - true_negatives_74: 44.0000
# Restored model, accuracy: 67.95%
# Restored model, recall: 60.00%
# Restored model, precision: 32.14%
# Restored model, Specificity:  69.84126984126983
# Restored model, AUC: 65.93%
# Restored model, true positives:  9.0
# Restored model, false positives:  19.0
# Restored model, false negatives:  6.0
# Restored model, true negatives:  44.0
# Accuracy:  67.94871794871796 %
# Recall:  53.333333333333336 %
# Precision:  30.76923076923077 %
# AUC:  66.66666666666666 %
# Specificity:  71.42857142857143 %
# 0.6666666666666666 AUC
# Best Threshold=0.551080, G-Mean=1.390
#
# -------------------------------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------------------------------
# Accuracy: 61.791 %
# Recall: 56.2347 %
# Precision: 40.4306 %
# AUC: 64.8099 %
# Specificity: 64.0016 %

# %% [markdown]
# ## Hosmer-Lemeshow test
# `data.json` files contain predicted and actual values for each sample of the test set, for each one of the five different splits of the dataset resulting from the 5-fold cross validation. These values are given as input to the following R code, to calculate the Hosmer-Lemeshow test statistic of the model.
#
#
# ```
# library(ResourceSelection)
# hl <- hoslem.test(x, y, g=10)
# hl
# ```
#
# where x contains the predicted values and y the actual values of one of the 5 iterations

# %%
y_pred = []
for i in ACTUAL:
  preds = []
  for j in i:
    preds.append(j[0])
  y_pred.append(preds)

# %%
prs = []
for j in range(5):
  tmp2 = []
  tmp1 = calculate_mean_probabilities(PRED[j])
  pr = get_total_predictions(tmp1, 0.5)
  prs.append(list(pr))

# %%
mydict = {"Predicted": prs[0], "Actual": y_pred[0]}
with open('data1.json', 'w') as fp:
    json.dump(str(mydict), fp)
mydict = {"Predicted": prs[1], "Actual": y_pred[1]}
with open('data2.json', 'w') as fp:
    json.dump(str(mydict), fp)
mydict = {"Predicted": prs[2], "Actual": y_pred[2]}
with open('data3.json', 'w') as fp:
    json.dump(str(mydict), fp)
mydict = {"Predicted": prs[3], "Actual": y_pred[3]}
with open('data4.json', 'w') as fp:
    json.dump(str(mydict), fp)
mydict = {"Predicted": prs[4], "Actual": y_pred[4]}
with open('data5.json', 'w') as fp:
    json.dump(str(mydict), fp)
